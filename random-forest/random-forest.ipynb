# %%
#importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
#transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
#divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
#criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 100)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier()

# %%
#visualização dos atributos principais
floresta.estimators_
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=1638212797),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1580751756),
#  DecisionTreeClassifier(max_features='sqrt', random_state=655573895),
#  DecisionTreeClassifier(max_features='sqrt', random_state=668957998),
#  DecisionTreeClassifier(max_features='sqrt', random_state=17376318),
#  DecisionTreeClassifier(max_features='sqrt', random_state=489594403),
#  DecisionTreeClassifier(max_features='sqrt', random_state=85454937),
#  DecisionTreeClassifier(max_features='sqrt', random_state=556314509),
#  DecisionTreeClassifier(max_features='sqrt', random_state=672222108),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1690383257),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1982271131),
#  DecisionTreeClassifier(max_features='sqrt', random_state=629022918),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1594577468),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1160814104),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1219914667),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1739355788),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1808910861),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2015793294),
#  DecisionTreeClassifier(max_features='sqrt', random_state=856509157),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1725679641),
#  DecisionTreeClassifier(max_features='sqrt', random_state=474040848),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1859209002),
#  DecisionTreeClassifier(max_features='sqrt', random_state=729280045),
#  DecisionTreeClassifier(max_features='sqrt', random_state=530472175),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1510811319),
#  DecisionTreeClassifier(max_features='sqrt', random_state=669291162),
#  DecisionTreeClassifier(max_features='sqrt', random_state=764952658),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1540892404),
#  DecisionTreeClassifier(max_features='sqrt', random_state=548106497),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1427197045),
#  DecisionTreeClassifier(max_features='sqrt', random_state=839619463),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1550953251),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1725817330),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1265692868),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1349376932),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1205614930),
#  DecisionTreeClassifier(max_features='sqrt', random_state=844392131),
#  DecisionTreeClassifier(max_features='sqrt', random_state=865021712),
#  DecisionTreeClassifier(max_features='sqrt', random_state=274734295),
#  DecisionTreeClassifier(max_features='sqrt', random_state=837922664),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1013140348),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1911764288),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1614294645),
#  DecisionTreeClassifier(max_features='sqrt', random_state=551447965),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1892887467),
#  DecisionTreeClassifier(max_features='sqrt', random_state=183604039),
#  DecisionTreeClassifier(max_features='sqrt', random_state=417081606),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1916409927),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1654625132),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1883358143),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1686593224),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1149827253),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1755472044),
#  DecisionTreeClassifier(max_features='sqrt', random_state=892263946),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1466684839),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1470415848),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1987590323),
#  DecisionTreeClassifier(max_features='sqrt', random_state=354551182),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1330040534),
#  DecisionTreeClassifier(max_features='sqrt', random_state=7406108),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1408507727),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2024117188),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1248634745),
#  DecisionTreeClassifier(max_features='sqrt', random_state=98593651),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1653665720),
#  DecisionTreeClassifier(max_features='sqrt', random_state=530845566),
#  DecisionTreeClassifier(max_features='sqrt', random_state=704159382),
#  DecisionTreeClassifier(max_features='sqrt', random_state=149183970),
#  DecisionTreeClassifier(max_features='sqrt', random_state=855486818),
#  DecisionTreeClassifier(max_features='sqrt', random_state=245105016),
#  DecisionTreeClassifier(max_features='sqrt', random_state=147665726),
#  DecisionTreeClassifier(max_features='sqrt', random_state=817742855),
#  DecisionTreeClassifier(max_features='sqrt', random_state=520508821),
#  DecisionTreeClassifier(max_features='sqrt', random_state=921595804),
#  DecisionTreeClassifier(max_features='sqrt', random_state=827597479),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1572210723),
#  DecisionTreeClassifier(max_features='sqrt', random_state=793643794),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1511535516),
#  DecisionTreeClassifier(max_features='sqrt', random_state=790944479),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1260822906),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1501012521),
#  DecisionTreeClassifier(max_features='sqrt', random_state=91587379),
#  DecisionTreeClassifier(max_features='sqrt', random_state=876072255),
#  DecisionTreeClassifier(max_features='sqrt', random_state=952428594),
#  DecisionTreeClassifier(max_features='sqrt', random_state=897966288),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1067403173),
#  DecisionTreeClassifier(max_features='sqrt', random_state=299016546),
#  DecisionTreeClassifier(max_features='sqrt', random_state=700703508),
#  DecisionTreeClassifier(max_features='sqrt', random_state=884902047),
#  DecisionTreeClassifier(max_features='sqrt', random_state=491678629),
#  DecisionTreeClassifier(max_features='sqrt', random_state=376094860),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1808539932),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1175246394),
#  DecisionTreeClassifier(max_features='sqrt', random_state=629155446),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1289173289),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1281107086),
#  DecisionTreeClassifier(max_features='sqrt', random_state=49370692),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1031626805),
#  DecisionTreeClassifier(max_features='sqrt', random_state=2033228969),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1754336493)]

# %%
previsoes = floresta.predict(X_teste)
confusao = confusion_matrix(y_teste, previsoes)
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7766666666666666
